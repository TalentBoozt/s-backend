# %%
import pandas as pd
from scipy.sparse import csr_matrix
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
df_encoded = pd.read_csv("E:/PROJECTS/spring boot/Talentboozt-projects/s-backend/src/main/resources/training/events_data_cleaned.csv", dtype={'9': str})
# Out:
# C:\Users\KAVI\AppData\Local\Temp\ipykernel_2152\686656366.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_encoded = pd.read_csv("E:/PROJECTS/spring boot/Talentboozt-projects/s-backend/src/main/resources/training/events_data_cleaned.csv", dtype={'9': str})

# %%
df_encoded.head()
# Out:
#     trackingId    url         sessionId        userId screenResolution  \
# 0  talentboozt      /  sess_8xg3veyis8f  unknown_user          385x854
# 1  talentboozt  /home  sess_8xg3veyis8f  unknown_user          385x854
# 2  talentboozt  /home  sess_8xg3veyis8f  unknown_user          385x854
# 3  talentboozt  /home  sess_rjwwegwilta  unknown_user         1440x718
# 4  talentboozt  /home  sess_rjwwegwilta  unknown_user         1440x718
#
#   language         ip   region     city timezone  ...  country_South Korea  \
# 0    en-US  127.0.0.1  unknown  unknown      NaN  ...                False
# 1    en-US  127.0.0.1  unknown  unknown      NaN  ...                False
# 2    en-US  127.0.0.1  unknown  unknown      NaN  ...                False
# 3    en-US  127.0.0.1  unknown  unknown      NaN  ...                False
# 4    en-US  127.0.0.1  unknown  unknown      NaN  ...                False
#
#    country_Sri Lanka  country_Sweden  country_Switzerland  \
# 0              False           False                False
# 1              False           False                False
# 2              False           False                False
# 3              False           False                False
# 4              False           False                False
#
#    country_The Netherlands  country_United Arab Emirates  \
# 0                    False                         False
# 1                    False                         False
# 2                    False                         False
# 3                    False                         False
# 4                    False                         False
#
#    country_United Kingdom  country_United States country_Vietnam  \
# 0                   False                  False           False
# 1                   False                  False           False
# 2                   False                  False           False
# 3                   False                  False           False
# 4                   False                  False           False
#
#    country_unknown
# 0             True
# 1             True
# 2             True
# 3             True
# 4             True
#
# [5 rows x 1830 columns]

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134911 entries, 0 to 134910
# Columns: 1830 entries, trackingId to country_unknown
# dtypes: bool(1806), float64(11), object(13)
# memory usage: 257.1+ MB

# %%
df_encoded.describe()
# Out:
#               clickX        clickY  scrollPercent    durationMs   domLoadTime  \
# count  134911.000000  134911.00000   1.349110e+05  1.349110e+05  1.349110e+05
# mean      190.349845     112.61989   1.012270e-16  5.730226e-17  7.516971e-17
# std       354.804290     193.91340   1.000004e+00  1.000004e+00  1.000004e+00
# min        -4.000000     -87.00000  -1.436008e+00 -8.729919e-02 -6.884521e-01
# 25%         0.000000       0.00000  -2.457288e-02 -7.514231e-02 -3.230894e-02
# 50%         0.000000       0.00000  -2.457288e-02 -7.514231e-02 -3.230894e-02
# 75%       243.000000     184.00000  -2.457288e-02 -7.514231e-02 -3.230894e-02
# max      2237.000000    1901.00000   2.288690e+02  1.573090e+02  2.409115e+02
#
#        fullLoadTime          ttfb      downlink           rtt      errorLine  \
# count  1.349110e+05  1.349110e+05  1.349110e+05  1.349110e+05  134911.000000
# mean  -5.056082e-17  8.342535e-17 -2.094060e-16  2.852473e-16       0.315601
# std    1.000004e+00  1.000004e+00  1.000004e+00  1.000004e+00      48.735389
# min   -2.221919e+01 -7.252137e-01 -5.695020e+00 -2.711386e+00       0.000000
# 25%    4.502954e-02 -5.146630e-02  7.750680e-02 -5.709068e-03       0.000000
# 50%    4.502954e-02 -5.146630e-02  7.750680e-02 -5.709068e-03       0.000000
# 75%    4.502954e-02 -5.146630e-02  7.750680e-02 -5.709068e-03       0.000000
# max    4.502986e-02  1.256900e+02  2.551447e+00  5.140215e+01    7982.000000
#
#          errorColumn
# count  134911.000000
# mean       20.699624
# std       727.375107
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max     92052.000000

# %%
# Convert the dataframe to a sparse matrix
X_sparse = csr_matrix(df_encoded.values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\sparse\_base.py:371, in _spbase.asformat(self, format, copy)
#     370 try:
# --> 371     return convert_method(copy=copy)
#     372 except TypeError:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\sparse\_coo.py:412, in _coo_base.tocsr(self, copy)
#     411 indices = np.empty_like(col, dtype=idx_dtype)
# --> 412 data = np.empty_like(self.data, dtype=upcast(self.dtype))
#     414 coo_tocsr(M, N, self.nnz, row, col, self.data,
#     415           indptr, indices, data)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\sparse\_sputils.py:53, in upcast(*args)
#      51         return t
# ---> 53 raise TypeError(f'no supported conversion for types: {args!r}')
#
# TypeError: no supported conversion for types: (dtype('O'),)
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Convert the dataframe to a sparse matrix
# ----> 2 X_sparse = csr_matrix(df_encoded.values)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\sparse\_compressed.py:83, in _cs_matrix.__init__(self, arg1, shape, dtype, copy)
#      80     except Exception as e:
#      81         raise ValueError("unrecognized {}_matrix constructor usage"
#      82                          "".format(self.format)) from e
# ---> 83     self._set_self(self.__class__(
#      84         self._coo_container(arg1, dtype=dtype)
#      85     ))
#      87 # Read matrix dimensions given, if any
#      88 if shape is not None:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\sparse\_compressed.py:32, in _cs_matrix.__init__(self, arg1, shape, dtype, copy)
#      30         arg1 = arg1.copy()
#      31     else:
# ---> 32         arg1 = arg1.asformat(self.format)
#      33     self._set_self(arg1)
#      35 elif isinstance(arg1, tuple):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\sparse\_base.py:373, in _spbase.asformat(self, format, copy)
#     371     return convert_method(copy=copy)
#     372 except TypeError:
# --> 373     return convert_method()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\sparse\_coo.py:412, in _coo_base.tocsr(self, copy)
#     410 indptr = np.empty(M + 1, dtype=idx_dtype)
#     411 indices = np.empty_like(col, dtype=idx_dtype)
# --> 412 data = np.empty_like(self.data, dtype=upcast(self.dtype))
#     414 coo_tocsr(M, N, self.nnz, row, col, self.data,
#     415           indptr, indices, data)
#     417 x = self._csr_container((data, indices, indptr), shape=self.shape)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\sparse\_sputils.py:53, in upcast(*args)
#      50         _upcast_memo[hash(args)] = t
#      51         return t
# ---> 53 raise TypeError(f'no supported conversion for types: {args!r}')
#
# TypeError: no supported conversion for types: (dtype('O'),)
